# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author:
# Dante Maximiliano Andrade Bautista

# %% [markdown]
# In this notebook, we summarize the Data Science Tools and Ecosystem. It is a practice exercise for getting started with Jupyter Notebooks and Github.

# %% [markdown]
# **Objectives**
# + Name some of the most popular languages for Data Science
# + Name some of the most popular libraries for Data Science
# + Name some of the most popular Data Science Tools

# %% [markdown]
# Some of the most popular languages for Data Science are:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Julia

# %% [markdown]
# Some of the most used libraries used by data scientist are:
# 1. pandas (Python)
# 2. pumpy (Python)
# 3. matplotlib (Python)
# 4. ggplot (R)
# 5. dplyr (R)
# 6. caret (R)

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook-Jupyter lab|
# |RStudio|
# |Visual Studio Code|

# %% [markdown]
# ### Here are some examples of arithmetic expressions in Python

# %%
# Here is an example of evaluating arithmetic expressions. In this case, multiplying and then adding integers.
(3*4)+5
# Out:
# 17

# %%
# Below, we can see how 200 minutes are converted to hours by dividing by 60.
(200/60)
# Out:
# 3.3333333333333335
